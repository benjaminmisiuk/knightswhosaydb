# %%
import knightswhosaydb as kdb

# %%
kdb
# Out:
# <module 'knightswhosaydb' from '/ssd/src/themachinethatgoesping/knightswhosaydb/src/knightswhosaydb/__init__.py'>

# %%
kdb.mosaic(
    dir_path = "/home/data/test_data/Egmont_Key/kmall/",
    format = 'kmall',
    out_lines = 'lines',
    mosaic_path = 'egmont.tiff',
    crs = "epsg:6319"
)
# Out:
# Found 14 files
# Processing file 1 of 14: 0000_20240726_132023.kmall
# indexing file ⠈ 100% :02s<00m:00s]
# indexing file ⠐ 100% :02s<00m:00s] [Found: 36048 datagrams]
# Initializing ping interface ⠐ 0% :00s<00m:00s] [Done]
#   0%|          | 0/18958 [00:00<?, ?it/s]
# Processing file 2 of 14: 0001_20240726_133732.kmall
# indexing file ⠠ 100% :00s<00m:00s]
# indexing file ⢀ 100% :00s<00m:00s] [Found: 13319 datagrams]
# Initializing ping interface ⠐ 0% :00s<00m:00s] [Done]
#   0%|          | 0/7027 [00:00<?, ?it/s]
# Processing file 3 of 14: 0003_20240726_135910.kmall
# indexing file ⢀ 100% :01s<00m:00s]
# indexing file ⡀ 100% :01s<00m:00s] [Found: 24445 datagrams]
# Initializing ping interface ⠐ 0% :00s<00m:00s] [Done]
#   0%|          | 0/13407 [00:00<?, ?it/s]
# Processing file 4 of 14: 0004_20240726_141430.kmall
# indexing file ⡀ 100% :01s<00m:00s]
# indexing file ⠄ 100% :01s<00m:00s] [Found: 18377 datagrams]
# Initializing ping interface ⠐ 0% :00s<00m:00s] [Done]
# ...
